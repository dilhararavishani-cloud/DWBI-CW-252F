# %%
pip install pandas ydata-profiling
# Out:
# Requirement already satisfied: pandas in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.3)
# Requirement already satisfied: ydata-profiling in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (4.18.4)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: minify-html>=0.15.0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (2.34.2)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (4.70.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (4.6.0)
# Requirement already satisfied: imagehash==4.3.2 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages (from pydantic<3,>=2->ydata-profiling) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.7.22)
# Requirement already satisfied: patsy>=0.5.6 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

file_name = "2020_al_data_kaggle_upload_new_old_syllabi.csv"

print("=" * 60)
print("1. LOADING AND CLEANING DATASET")
print("=" * 60)

# Load data treating '-' and spaces as NaN
df = pd.read_csv(file_name, na_values=["-", "", " ", "Absent"])

# Convert Zscore to numeric
if "Zscore" in df.columns:
    df["Zscore"] = pd.to_numeric(df["Zscore"], errors="coerce")

# Extract numeric values from rank strings (e.g. '4336 (NEW)' -> 4336)
for rank_col in ["district_rank", "island_rank"]:
    if rank_col in df.columns:
        df[f"{rank_col}_num"] = (
            df[rank_col]
            .astype(str)
            .str.extract(r"(\d+)")
            .astype(float)
        )

print(f"Total Records (Rows): {df.shape[0]:,}")
print(f"Total Columns:        {df.shape[1]}")
print(f"Duplicate Rows:       {df.duplicated().sum():,}")

print("\n" + "=" * 60)
print("2. COLUMN HEALTH & MISSING VALUES")
print("=" * 60)
overview = pd.DataFrame({
    "Data Type": df.dtypes,
    "Missing Count": df.isnull().sum(),
    "Missing (%)": (df.isnull().mean() * 100).round(2),
    "Unique Values": df.nunique()
})
print(overview.to_string())

print("\n" + "=" * 60)
print("3. NUMERIC SUMMARY STATISTICS")
print("=" * 60)
numeric_summary = df.describe().T
print(numeric_summary.to_string())

print("\n" + "=" * 60)
print("4. CATEGORICAL DISTRIBUTIONS (TOP 5 VALUES PER COLUMN)")
print("=" * 60)
categorical_cols = df.select_dtypes(include=["object", "category"]).columns

for col in categorical_cols:
    print(f"\n--- Distribution: {col} ---")
    val_counts = df[col].value_counts(dropna=False).head(5)
    percentages = (df[col].value_counts(normalize=True, dropna=False) * 100).round(2).head(5)
    dist_df = pd.DataFrame({"Count": val_counts, "Percentage (%)": percentages})
    print(dist_df.to_string())

# Export summary to CSV files for easy review
overview.to_csv("profile_column_health.csv")
numeric_summary.to_csv("profile_numeric_summary.csv")
print("\n[Done] Summary tables exported to 'profile_column_health.csv' and 'profile_numeric_summary.csv'.")
# Out:
# ============================================================
# 1. LOADING AND CLEANING DATASET
# ============================================================
# C:\Users\Asus\AppData\Local\Temp\ipykernel_14352\1321407183.py:11: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, na_values=["-", "", " ", "Absent"])
# Total Records (Rows): 337,553
# Total Columns:        21
# Duplicate Rows:       0
#
# ============================================================
# 2. COLUMN HEALTH & MISSING VALUES
# ============================================================
#                   Data Type  Missing Count  Missing (%)  Unique Values
# index                 int64              0         0.00         337553
# stream               object         150514        44.59              7
# Zscore              float64         105249        31.18          33890
# district_rank        object         153254        45.40           8059
# island_rank          object         153254        45.40          47615
# al_year               int64              0         0.00              1
# sub1                 object              0         0.00             51
# sub1_r               object          43581        12.91              6
# sub2                 object              0         0.00             60
# sub2_r               object          45556        13.50              6
# sub3                 object              0         0.00             60
# sub3_r               object          43332        12.84              7
# cgt_r                object          76628        22.70            116
# ge_r                 object          66140        19.59              6
# syllabus             object              0         0.00              2
# birth_day            object              0         0.00             34
# birth_month          object              0         0.00             15
# birth_year           object              0         0.00             76
# gender               object           1484         0.44              3
# district_rank_num   float64         153254        45.40           7501
# island_rank_num     float64         153254        45.40          42071
#
# ============================================================
# 3. NUMERIC SUMMARY STATISTICS
# ============================================================
#                       count           mean           std        min         25%          50%          75%          max
# index              337553.0  168776.000000  97443.302045     0.0000  84388.0000  168776.0000  253164.0000  337552.0000
# Zscore             232304.0       0.305389      0.763854    -1.9383     -0.3002       0.2217       0.8528       3.5583
# al_year            337553.0    2020.000000      0.000000  2020.0000   2020.0000    2020.0000    2020.0000    2020.0000
# district_rank_num  184299.0    1304.358743   1423.551699     1.0000    269.0000     783.0000    1859.0000    7546.0000
# island_rank_num    184299.0   21584.624876  19429.420980     1.0000   5800.0000   15425.0000   33040.0000   73006.0000
#
# ============================================================
# 4. CATEGORICAL DISTRIBUTIONS (TOP 5 VALUES PER COLUMN)
# ============================================================
#
# --- Distribution: stream ---
#                      Count  Percentage (%)
# stream
# NaN                 150514           44.59
# ARTS                 76547           22.68
# COMMERCE             39877           11.81
# BIOLOGICAL SCIENCE   25768            7.63
# PHYSICAL SCIENCE     21776            6.45
#
# --- Distribution: district_rank ---
#                 Count  Percentage (%)
# district_rank
# NaN            153254           45.40
# 11 (NEW)          152            0.05
# 9 (NEW)           151            0.04
# 6 (NEW)           150            0.04
# 1 (NEW)           150            0.04
#
# --- Distribution: island_rank ---
#               Count  Percentage (%)
# island_rank
# NaN          153254           45.40
# 15404 (NEW)      21            0.01
# 10175 (NEW)      19            0.01
# 10890 (NEW)      19            0.01
# 20768 (NEW)      17            0.01
#
# --- Distribution: sub1 ---
#                                         Count  Percentage (%)
# sub1
# PHYSICS                                 88758           26.29
# ECONOMICS                               66538           19.71
# GEOGRAPHY                               52478           15.55
# POLITICAL SCIENCE                       36859           10.92
# INFORMATION & COMMUNICATION TECHNOLOGY  35337           10.47
#
# --- Distribution: sub1_r ---
#         Count  Percentage (%)
# sub1_r
# S       97338           28.84
# F       79006           23.41
# C       71764           21.26
# NaN     43581           12.91
# B       27111            8.03
#
# --- Distribution: sub2 ---
#                         Count  Percentage (%)
# sub2
# CHEMISTRY               83993           24.88
# BUSINESS STUDIES        62466           18.51
# BUDDHIST CIVILIZATION   27395            8.12
# ENGINEERING TECHNOLOGY  24388            7.22
# POLITICAL SCIENCE       18830            5.58
#
# --- Distribution: sub2_r ---
#         Count  Percentage (%)
# sub2_r
# S       89408           26.49
# C       80261           23.78
# F       59559           17.64
# NaN     45556           13.50
# B       37328           11.06
#
# --- Distribution: sub3 ---
#                         Count  Percentage (%)
# sub3
# SINHALA                 75708           22.43
# ACCOUNTING              64900           19.23
# BIOLOGY                 50723           15.03
# COMBINED MATHEMATICS    39094           11.58
# SCIENCE FOR TECHNOLOGY  37869           11.22
#
# --- Distribution: sub3_r ---
#         Count  Percentage (%)
# sub3_r
# S       88383           26.18
# C       75781           22.45
# F       55258           16.37
# B       46710           13.84
# NaN     43332           12.84
#
# --- Distribution: cgt_r ---
#        Count  Percentage (%)
# cgt_r
# NaN    76628           22.70
# 040    12647            3.75
# 042    12475            3.70
# 038    12080            3.58
# 044    11782            3.49
#
# --- Distribution: ge_r ---
#        Count  Percentage (%)
# ge_r
# F     123804           36.68
# S      69820           20.68
# NaN    66140           19.59
# C      36080           10.69
# A      23093            6.84
#
# --- Distribution: syllabus ---
#            Count  Percentage (%)
# syllabus
# new       306211           90.71
# old        31342            9.29
#
# --- Distribution: birth_day ---
#            Count  Percentage (%)
# birth_day
# 1          11297            3.35
# 10         11296            3.35
# 21         11265            3.34
# 20         11199            3.32
# 23         11188            3.31
#
# --- Distribution: birth_month ---
#              Count  Percentage (%)
# birth_month
# May          29424            8.72
# October      29350            8.69
# March        29203            8.65
# April        28714            8.51
# January      28616            8.48
#
# --- Distribution: birth_year ---
#              Count  Percentage (%)
# birth_year
# 2001        185402           54.93
# 2000         90735           26.88
# 1999         24155            7.16
# 2002         16236            4.81
# 1998          6561            1.94
#
# --- Distribution: gender ---
#               Count  Percentage (%)
# gender
# female       193326           57.27
# male         142719           42.28
# NaN            1484            0.44
# Major error      24            0.01
#
# [Done] Summary tables exported to 'profile_column_health.csv' and 'profile_numeric_summary.csv'.
